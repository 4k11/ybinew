# %% [markdown]
# ### **Bike Price Prediction using Linear Regression**

# %% [markdown]
# **Import Library**

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# **Import CSV as DataFrame**

# %%
df = pd.read_csv(r'https://github.com/YBI-Foundation/Dataset/raw/main/Bike%20Prices.csv')

# %% [markdown]
# **Get the First Five Rows of DataFrame**

# %%
df.head()
# Out:
#    Brand               Model  Selling_Price  Year Seller_Type      Owner  \
# 0    TVS          TVS XL 100          30000  2017  Individual  1st owner
# 1  Bajaj       Bajaj  ct 100          18000  2017  Individual  1st owner
# 2     Yo            Yo Style          20000  2011  Individual  1st owner
# 3  Bajaj  Bajaj Discover 100          25000  2010  Individual  1st owner
# 4  Bajaj  Bajaj Discover 100          24999  2012  Individual  2nd owner
#
#    KM_Driven  Ex_Showroom_Price
# 0       8000            30490.0
# 1      35000            32000.0
# 2      10000            37675.0
# 3      43000            42859.0
# 4      35000            42859.0

# %% [markdown]
# **Get Information of DataFrame**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1061 entries, 0 to 1060
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Brand              1061 non-null   object
#  1   Model              1061 non-null   object
#  2   Selling_Price      1061 non-null   int64
#  3   Year               1061 non-null   int64
#  4   Seller_Type        1061 non-null   object
#  5   Owner              1061 non-null   object
#  6   KM_Driven          1061 non-null   int64
#  7   Ex_Showroom_Price  626 non-null    float64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 66.4+ KB

# %% [markdown]
# **Get Missing Values Drop**

# %%
df = df.dropna()

# %% [markdown]
# **Get Summary Statistics**

# %%
df.describe()
# Out:
#        Selling_Price         Year      KM_Driven  Ex_Showroom_Price
# count     626.000000   626.000000     626.000000       6.260000e+02
# mean    59445.164537  2014.800319   32671.576677       8.795871e+04
# std     59904.350888     3.018885   45479.661039       7.749659e+04
# min      6000.000000  2001.000000     380.000000       3.049000e+04
# 25%     30000.000000  2013.000000   13031.250000       5.485200e+04
# 50%     45000.000000  2015.000000   25000.000000       7.275250e+04
# 75%     65000.000000  2017.000000   40000.000000       8.703150e+04
# max    760000.000000  2020.000000  585659.000000       1.278000e+06

# %% [markdown]
# **Get Categories and Counts of Categorical Variables**

# %%
df[['Brand']].value_counts()
# Out:
# Brand
# Honda       170
# Bajaj       143
# Hero        108
# Yamaha       94
# Royal        40
# TVS          23
# Suzuki       18
# KTM           6
# Mahindra      6
# Kawasaki      4
# UM            3
# Activa        3
# Harley        2
# Vespa         2
# BMW           1
# Hyosung       1
# Benelli       1
# Yo            1
# dtype: int64

# %%
df[['Model']].value_counts()
# Out:
# Model
# Honda Activa [2000-2015]                      23
# Honda CB Hornet 160R                          22
# Bajaj Pulsar 180                              20
# Yamaha FZ S V 2.0                             16
# Bajaj Discover 125                            16
#                                               ..
# Royal Enfield Thunderbird 500                  1
# Royal Enfield Continental GT [2013 - 2018]     1
# Royal Enfield Classic Stealth Black            1
# Royal Enfield Classic Squadron Blue            1
# Yo Style                                       1
# Length: 183, dtype: int64

# %%
df[['Seller_Type']].value_counts()
# Out:
# Seller_Type
# Individual     623
# Dealer           3
# dtype: int64

# %%
df[['Owner']].value_counts()
# Out:
# Owner
# 1st owner    556
# 2nd owner     66
# 3rd owner      3
# 4th owner      1
# dtype: int64

# %% [markdown]
# **Get Column Names**

# %%
df.columns
# Out:
# Index(['Brand', 'Model', 'Selling_Price', 'Year', 'Seller_Type', 'Owner',
#        'KM_Driven', 'Ex_Showroom_Price'],
#       dtype='object')

# %% [markdown]
# **Get Shape of DataFrame**

# %%
df.shape
# Out:
# (626, 8)

# %% [markdown]
# **Get Encoding of Categorical Features**

# %%
df.replace({'Seller_Type':{'Individual':0,'Dealer':1}},inplace=True)

# %%
df.replace({'Owner':{'1st owner':0, '2nd owner':1,'3rd owner':2,'4th owner':3}},inplace=True)

# %% [markdown]
# **Define y(dependent or label or target varaible) and X(independent or features or attribute Variable)**

# %%
y=df['Selling_Price']

# %%
y.shape
# Out:
# (626,)

# %%
y
# Out:
# 0       30000
# 1       18000
# 2       20000
# 3       25000
# 4       24999
#         ...
# 621    330000
# 622    300000
# 623    425000
# 624    760000
# 625    750000
# Name: Selling_Price, Length: 626, dtype: int64

# %%
X=df[['Year','Seller_Type', 'Owner', 'KM_Driven', 'Ex_Showroom_Price']]

# %%
X.shape
# Out:
# (626, 5)

# %%
X
# Out:
#      Year  Seller_Type  Owner  KM_Driven  Ex_Showroom_Price
# 0    2017            0      0       8000            30490.0
# 1    2017            0      0      35000            32000.0
# 2    2011            0      0      10000            37675.0
# 3    2010            0      0      43000            42859.0
# 4    2012            0      1      35000            42859.0
# ..    ...          ...    ...        ...                ...
# 621  2014            0      3       6500           534000.0
# 622  2011            0      0      12000           589000.0
# 623  2017            0      1      13600           599000.0
# 624  2019            0      0       2800           752020.0
# 625  2013            0      1      12000          1278000.0
#
# [626 rows x 5 columns]

# %% [markdown]
# **Get Train Test Split**

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test, y_train,y_test = train_test_split(X,y,test_size =0.3, random_state =12529)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((438, 5), (188, 5), (438,), (188,))

# %% [markdown]
# **Get Model Train**

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# **Get Model Prediction**

# %%
y_pred = lr.predict(X_test)

# %%
y_pred.shape
# Out:
# (188,)

# %%
y_pred
# Out:
# array([ 52652.60893427,  39486.4167618 , 196562.4319859 ,  55580.50406352,
#         26140.72948174,  94608.16940207, 119187.31851378,  68882.36906452,
#         33660.46971137,  46944.42315337,  53461.39448306,  11010.80661868,
#         33332.52261296,  99136.85017244,  53520.69363008,  77889.92667441,
#         45898.51705697,  51568.32996293,  23936.19734586,  53169.07821729,
#         93240.71089043,   -982.05901739,  72782.26710894,  61648.18639177,
#         60975.53326569,  29005.69236303,  52733.45578056,  76744.27220671,
#         25899.12686659,  38977.38046566, 136552.24672457,  43207.37077008,
#         59999.13518359, 178300.52079417,  56538.55902123,  21881.41938334,
#         39242.90242201,  32072.273444  ,  54250.50343733,  39760.72648089,
#         58983.84447853,  30360.33221387,  53733.14061812,  39812.75115886,
#        135490.92768463,  44412.40326892,   7898.88343971,  52017.36847526,
#         42026.43374393, 104169.266507  ,  60024.05156232, 101703.69488336,
#         73823.40634538,   7418.53528021,  28994.62378809,  26468.30379689,
#         58732.87189519,  24064.07758699,  22054.26970934,  96688.09028923,
#         49059.60157507, 149306.70799826,  35995.2788715 ,  56235.97097101,
#        155880.34537452, 103229.27553889, 118839.81801378,  -4400.37997651,
#         29439.79781321,  70995.09147179,  30768.12967092,  56391.40902527,
#         70106.66220849,  89098.33049163, 350498.83144351,  57599.65779785,
#         61284.42259903,  51994.07673435,  52266.05783206,  40936.6078096 ,
#         31783.57796454,  45235.90798601,  18126.24685081,  55728.8323743 ,
#        123106.08328155,  36957.36642604,  54105.13423644,  53106.1998488 ,
#         46915.53621662,  26975.12879398,  53457.41832255,  49221.50886951,
#        405104.5762913 ,  26408.33619495,  35114.81521374,  36983.34162717,
#         39544.3335118 ,  22170.10320934,  66661.33393212,  65221.83868648,
#         63184.58572119,   8219.81705322,  47459.79434856,  39363.94214113,
#         53737.3461139 ,  44086.30857564,  67095.518973  ,  75758.29375952,
#        132086.83399611,  68670.00764785,  22145.56947711, 115599.13224027,
#         58947.47158094, 119492.34673045,  52789.15224524,  33853.85015867,
#         24614.59975475,  41758.07556633,  54716.52808318,  61963.51345746,
#         52911.14478899,  79992.53011008,  29672.22354323,  43025.2740096 ,
#         42464.26648449,  60340.66312899,  57087.75135548,  55532.76882007,
#         50834.66685813,  50064.17609673,  33777.58022365,  69345.63512728,
#         29407.0585768 ,  63759.75033499,  65697.08116449,   6868.42621988,
#        145514.86003012,  22423.07191628,  68523.77051712, -12076.49020563,
#         41944.35163787,  70727.85652738,  50548.08989736,  52879.93137833,
#         24235.53641316,  65257.46077036,  41925.69184501,  55972.52034755,
#         22054.26970934,  55214.21373795,  16299.4777373 , 103976.21067367,
#         89730.4115583 ,  93124.87739043,  32629.09307008,  25510.96281868,
#         47409.12768998,  32270.96436235, 144891.0631555 ,  24503.84743594,
#         20472.25040593,  51752.80978899,  60363.44082618,  39539.28344414,
#         75319.87432595,  30491.06261349,  13752.49475224,  22966.27623787,
#         40682.77662615,  51692.03443887,  45360.47707564,  48355.62490686,
#         16922.07641164, 160218.45492345, -13296.86796353,  38887.94367846,
#         93468.23846857,  24948.38574989,  60339.69784982,  60108.99612899,
#         52196.98997508,  64756.57564077,  25703.96236823,  88403.32949163,
#        122780.03432149, 107117.07767768,  75475.87519073,  31827.55654721])

# %% [markdown]
# **Get Model Evaluation**

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 280339916.89734465

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 11298.505848530413

# %%
r2_score(y_test, y_pred)
# Out:
# 0.8473238209287886

# %% [markdown]
# **Get Visualization of Actual Vs Predicted Results**

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test,y_pred)
plt.xlabel('Actual Prices')
plt.ylabel('Predicted Prices')
plt.title('Actual Price vs Predicted Price')
plt.show()

# %% [markdown]
# **Get Future Predictions**

# %%
df_new = df.sample(1)

# %%
df_new
# Out:
#     Brand               Model  Selling_Price  Year  Seller_Type  Owner  \
# 357  Hero  Hero Xtreme Sports          65000  2017            0      0
#
#      KM_Driven  Ex_Showroom_Price
# 357      23000            78350.0

# %%
df_new.shape
# Out:
# (1, 8)

# %%
X_new = df_new.drop(['Brand', 'Model', 'Selling_Price'],axis = 1)

# %%
y_pred_new = lr.predict(X_new)

# %%
y_pred_new
# Out:
# array([64472.06992367])
